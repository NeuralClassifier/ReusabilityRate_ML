# %% [markdown]
# <a href="https://colab.research.google.com/github/NeuralClassifier/ReusabilityRate_ML/blob/main/CMPUT_663_ReuseRate_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U scikit-learn==1.0.1
# !pip install -U tensorflow==2.7.0
# !pip install -U seaborn==0.11.2
# !pip install -U matplotlib==3.5.0
# !pip install -U pandas==1.3.4

# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import  LogisticRegression
from sklearn.linear_model import BayesianRidge
from sklearn.linear_model import SGDRegressor
from xgboost import XGBRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import ElasticNet
from sklearn.svm import SVR

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold 
from sklearn.metrics import mean_absolute_error 
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
import statistics

import warnings

# %%
# !pip install -U scikit-learn==1.0.1
# !git install -U tensorflow==2.7.0
# !pip install -U seaborn==0.11.2
# !pip install -U matplotlib==3.5.0
# !pip install -U pandas==1.3.4
# Out:
# Cloning into 'ReusabilityRate_ML'...
# remote: Enumerating objects: 147, done.
# remote: Counting objects: 100% (147/147), done.
# remote: Compressing objects: 100% (139/139), done.
# remote: Total 147 (delta 61), reused 15 (delta 6), pack-reused 0
# Receiving objects: 100% (147/147), 9.04 MiB | 11.78 MiB/s, done.
# Resolving deltas: 100% (61/61), done.

# %%
data = pd.read_excel('DataSets/NoClass_to_rate.xlsx')
data.drop(['Unnamed: 0'],axis=1,inplace=True)
data
# Out:
#                                               Project  ...  AvgReuseRateClass
# 0                      ch.qos.logback/logback-classic  ...           4.855172
# 1                    com.android.support/appcompat-v7  ...           3.003344
# 2      com.fasterxml.jackson.core/jackson-annotations  ...           2.055556
# 3         com.fasterxml.jackson.core/jackson-databind  ...           6.596262
# 4                           com.google.code.gson/gson  ...          14.506329
# 5                              com.google.guava/guava  ...           6.313933
# 6                             com.google.gwt/gwt-user  ...           3.402921
# 7                 commons-beanutils/commons-beanutils  ...           0.000000
# 8                         commons-codec/commons-codec  ...           6.000000
# 9             commons-collections/commons-collections  ...           0.055675
# 10                    commons-logging/commons-logging  ...          53.148148
# 11                                        dom4j/dom4j  ...           2.393750
# 12                                    javax.mail/mail  ...          13.716667
# 13                          javax.servlet/servlet-api  ...         105.357143
# 14                                joda-time/joda-time  ...          12.090909
# 15                                        junit/junit  ...          34.801471
# 16                                        log4j/log4j  ...           6.502762
# 17                   org.apache.commons/commons-lang3  ...           5.502128
# 18               org.apache.httpcomponents/httpclient  ...           1.905128
# 19                        org.apache.maven/maven-core  ...           4.704626
# 20                  org.apache.maven/maven-plugin-api  ...          74.812500
# 21                                org.clojure/clojure  ...           0.828804
# 22                            org.clojure/tools.nrepl  ...           1.250000
# 23              org.codehaus.jackson/jackson-core-asl  ...          19.359551
# 24            org.codehaus.jackson/jackson-mapper-asl  ...           2.233184
# 25                              org.easymock/easymock  ...           2.704545
# 26                     org.eclipse.jetty/jetty-server  ...           5.465116
# 27                          org.hamcrest/hamcrest-all  ...          12.487805
# 28                         org.hamcrest/hamcrest-core  ...          12.487805
# 29                      org.hamcrest/hamcrest-library  ...           0.526316
# 30                       org.hibernate/hibernate-core  ...           2.020548
# 31              org.hibernate/hibernate-entitymanager  ...           2.031299
# 32                  org.hibernate/hibernate-validator  ...           0.025875
# 33                            org.javassist/javassist  ...           3.138817
# 34                            org.mockito/mockito-all  ...           4.772500
# 35                           org.mockito/mockito-core  ...           4.772500
# 36                org.powermock/powermock-api-mockito  ...           1.115385
# 37              org.powermock/powermock-module-junit4  ...          25.571429
# 38                           org.projectlombok/lombok  ...           1.114846
# 39                        org.reflections/reflections  ...           2.963855
# 40                           org.slf4j/jcl-over-slf4j  ...         177.875000
# 41                             org.slf4j/jul-to-slf4j  ...          17.000000
# 42                                org.slf4j/slf4j-api  ...         167.520000
# 43                             org.slf4j/slf4j-simple  ...           0.000000
# 44                      org.spockframework/spock-core  ...           1.005025
# 45  org.springframework.boot/spring-boot-starter-test  ...           1.631579
# 46   org.springframework.boot/spring-boot-starter-web  ...           1.321277
# 47                     org.springframework/spring-aop  ...           0.926829
# 48                   org.springframework/spring-beans  ...          10.525180
# 49                 org.springframework/spring-context  ...           4.677419
# 50         org.springframework/spring-context-support  ...           1.707071
# 51                    org.springframework/spring-core  ...           6.818575
# 52                    org.springframework/spring-jdbc  ...           4.456731
# 53                    org.springframework/spring-test  ...          10.043796
# 54                      org.springframework/spring-tx  ...           5.886792
# 55                     org.springframework/spring-web  ...           4.052718
# 56                                  org.testng/testng  ...           2.895833
# 57                                  xerces/xercesImpl  ...           0.217228
#
# [58 rows x 3 columns]

# %%
df.iloc[:,3:-1]
# Out:
#             AD        CD       TCD  CLOC  TCLOC  ...  TNG  TNM  TNOS  TNPM  NCL
# 0     0.000000  0.000000  0.342362     0   4146  ...  217  853  3498   624    0
# 1     0.000000  0.000000  0.343269     0   4146  ...  217  853  3498   624    0
# 2     0.000000  0.000000  0.000000     0      0  ...    0    0     0     0    0
# 3     0.000000  0.000000  0.343269     0   4146  ...  217  853  3498   624    0
# 4     0.000000  0.000000  0.343269     0   4146  ...  217  853  3498   624    0
# ...        ...       ...       ...   ...    ...  ...  ...  ...   ...   ...  ...
# 2188  0.984127  0.498253  0.498253   713    713  ...   22   66   394    53   10
# 2189  0.701493  0.476530  0.476530  1137   1137  ...   17   91   732    59   10
# 2190  0.540636  0.482071  0.482071  1909   1909  ...   94  312   851   280   15
# 2191  0.700000  0.225403  0.225403  2543   2543  ...   34  290  4838    57   29
# 2192  0.458716  0.402589  0.402589   591    591  ...   22  138   414   127   18
#
# [2193 rows x 18 columns]

# %%
len(rtm.X_np[:,0])
# Out:
# 24794

# %%
warnings.filterwarnings('ignore')
class ReuseTradML:
  def __init__(self,level):
    self.ml_algo_list = ['PolR',
                         'MLPR',
                         'BR',
                         'SGDR',
                         'XGBR',
                         'DTR',
                         'EN',
                         'SVR']

    self.metrics = ['RMSE',
                    'MAE']
    self.data_columns = None
    self.level=level

    if self.level.lower() == 'package':
      target_scaler = MinMaxScaler()
      data = pd.read_excel('DataSets/packages.xlsx')
      data.drop(['Unnamed: 0'],axis=1,inplace=True)
      df = data.iloc[:,3:-1]
      self.data_columns = df.columns
      self.X_np = np.array(df)
      #target_scaler = MinMaxScaler()
      #target_scaler.fit(self.X_np)
      #self.X = target_scaler.transform(self.X_np)

      self.Y = data.iloc[:,-1]
      self.Y = self.Y.values.reshape(-1, 1)
      target_scaler = MinMaxScaler()
      target_scaler.fit(self.Y)
      self.Y = target_scaler.transform(self.Y)

      self.other = data.iloc[:,:3]

    elif self.level.lower() == 'class':
      target_scaler = MinMaxScaler()
      data = pd.read_excel('DataSets/classes.xlsx')
      data.drop(['Unnamed: 0'],axis=1,inplace=True)
      df = data.iloc[:,3:-1]
      self.data_columns = df.columns
      self.X_np = np.array(df)
      #target_scaler = MinMaxScaler()
      #target_scaler.fit(self.X_np)
      #self.X = target_scaler.transform(self.X_np)

      self.Y = data.iloc[:,-1]
      self.Y = self.Y.values.reshape(-1, 1)
      target_scaler = MinMaxScaler()
      target_scaler.fit(self.Y)
      self.Y = target_scaler.transform(self.Y)

      self.other = data.iloc[:,:3]

    elif self.level.lower() == 'class_frequency':
      target_scaler = MinMaxScaler()
      data = pd.read_excel('DataSets/NoClass_to_rate.xlsx')
      data.drop(['Unnamed: 0'],axis=1,inplace=True)
      df = data.iloc[:,1]
      #self.data_columns = df.columns
      self.X_np = np.array(df)
      target_scaler.fit(self.X_np.reshape(-1, 1))
      self.X = target_scaler.transform(self.X_np.reshape(-1, 1))

      self.Y = data.iloc[:,-1]
      self.Y = self.Y.values.reshape(-1, 1)
      target_scaler = MinMaxScaler()
      target_scaler.fit(self.Y)
      self.Y = target_scaler.transform(self.Y)

      #self.X_np = np.array(data.iloc[:,4:])
      #self.other = data.iloc[:,:4]
    
    elif self.level.lower() == 'package_frequency':
      target_scaler = MinMaxScaler()
      data = pd.read_excel('DataSets/NoPackage_to_rate.xlsx')
      data.drop(['Unnamed: 0'],axis=1,inplace=True)
      df = data.iloc[:,1]
      #self.data_columns = df.columns
      self.X_np = np.array(df)
      target_scaler.fit(self.X_np.reshape(-1, 1))
      self.X = target_scaler.transform(self.X_np.reshape(-1, 1))

      self.Y = data.iloc[:,-1]
      self.Y = self.Y.values.reshape(-1, 1)
      target_scaler = MinMaxScaler()
      target_scaler.fit(self.Y)
      self.Y = target_scaler.transform(self.Y)

      #self.X_np = np.array(data.iloc[:,4:])
      #self.other = data.iloc[:,:4]

    else:
      print('Error, Please try: class, package, or project. Thanks!')
      self.X=None
      self.Y=None
      self.other=None

  def apply_ml(self):
    kf = KFold(n_splits=10, random_state=None, shuffle=True)
  
    metric = []
    metric_count = 0

    level = []
    model = []

    mean_RMSE = []
    stdv_RMSE = []
    mean_MAE = []
    stdv_MAE = []

    if self.level.lower() == 'class' or self.level.lower() == 'package':

      for i in range(self.X_np.shape[1]):
        #print(self.X[i])
        for j in self.ml_algo_list:
          if j == 'PolR':
            
            #temp_data = self.X[i]
            level.append(self.level)
            metric.append(self.data_columns[i])

            cnt=0
            RMSE=[]
            MAE=[]
            poly_reg = PolynomialFeatures(degree=7)
            temp_data = poly_reg.fit_transform(self.X_np[:,i].reshape(-1, 1))
            pol_reg = LinearRegression()
            model.append('PolR')
            warnings.filterwarnings('ignore')
            print('Metric: ',self.data_columns[i])
            print('Level: ',self.level)
            print('Model: ',j)
            print()
            print("**************************************************************")
            print()
            print('At i: ',i,' x = ',self.X_np[:,i])
            print()

            for train_index, test_index in kf.split(temp_data):
              cnt = cnt+1
              #print('Fold: ',cnt)
              X_train, X_test = temp_data[train_index], temp_data[test_index]
              y_train, y_test = self.Y[train_index], self.Y[test_index]

              pol_reg.fit(X_train,y_train)
              y_pred = pol_reg.predict(X_test)
              RMSE.append(np.sqrt(mean_squared_error(y_test,y_pred)))
              MAE.append(mean_absolute_error(y_test,y_pred))
            
            mean_RMSE.append(statistics.mean(RMSE))
            stdv_RMSE.append(statistics.pstdev(RMSE))
            mean_MAE.append(statistics.mean(MAE))
            stdv_MAE.append(statistics.pstdev(MAE))

          else:
            
            warnings.filterwarnings('ignore')
            #['Polynomial Regression','MLPRegressor','BayesianRidge','SGD Regressor','XGB Regressor','Decision Tree Regressor','ElasticNet','SVM Regressor',]
            if j == 'MLPR':
              reg = MLPRegressor()
              print('Metric: ',self.data_columns[i])
              print('Level: ',self.level)
              print('Model: ',j)
              print()
              print("**************************************************************")
              print()
              model.append(j)

            #if j == 'Logistic Regression':
              #reg = LogisticRegression()
              #print('Metric: ',self.data_columns[i])
              #print('Level: ',self.level)
              #print('Model: ',j)

            if j == 'BR':
              reg = BayesianRidge()
              print('Metric: ',self.data_columns[i])
              print('Level: ',self.level)
              print('Model: ',j)
              print()
              print("**************************************************************")
              print()
              model.append(j)

            if j == 'SGDR':
              reg = SGDRegressor()
              print('Metric: ',self.data_columns[i])
              print('Level: ',self.level)
              print('Model: ',j)
              print()
              print("**************************************************************")
              print()
              model.append(j)

            if j == 'XGBR':
              reg = XGBRegressor()
              print('Metric: ',self.data_columns[i])
              print('Level: ',self.level)
              print('Model: ',j)
              print()
              print("**************************************************************")
              print()
              model.append(j)

            if j == 'DTR':
              reg = DecisionTreeRegressor()
              print('Metric: ',self.data_columns[i])
              print('Level: ',self.level)
              print('Model: ',j)
              print()
              print("**************************************************************")
              print()
              model.append(j)

            if j == 'EN':
              reg = ElasticNet()
              print('Metric: ',self.data_columns[i])
              print('Level: ',self.level)
              print('Model: ',j)
              print()
              print("**************************************************************")
              print()
              model.append(j)

            if j == 'SVR':
              reg = SVR()
              print('Metric: ',self.data_columns[i])
              print('Level: ',self.level)
              print('Model: ',j)
              print()
              print("**************************************************************")
              print()
              model.append(j)
            
            print('At i: ',i,' x = ',self.X_np[:,i])
            print()
            temp_data = self.X_np[:,i].reshape(-1, 1)
            target_scaler = MinMaxScaler()
            target_scaler.fit(temp_data)
            temp_data = target_scaler.transform(temp_data)
            level.append(self.level)
            metric.append(self.data_columns[i])

            cnt=0
            RMSE=[]
            MAE=[]
            for train_index, test_index in kf.split(temp_data):
              cnt = cnt+1
              #print('Fold: ',cnt)
              X_train, X_test = temp_data[train_index], temp_data[test_index]
              y_train, y_test = self.Y[train_index], self.Y[test_index]

              reg.fit(X_train,y_train)
              y_pred = reg.predict(X_test)
              RMSE.append(np.sqrt(mean_squared_error(y_test,y_pred)))
              MAE.append(mean_absolute_error(y_test,y_pred))

            mean_RMSE.append(statistics.mean(RMSE))
            stdv_RMSE.append(statistics.pstdev(RMSE))
            mean_MAE.append(statistics.mean(MAE))
            stdv_MAE.append(statistics.pstdev(MAE))
        

        

        #break
      metric = pd.DataFrame(metric,columns=['Metric'])
      level = pd.DataFrame(level,columns=['Level'])
      model = pd.DataFrame(model,columns=['Model'])
      print()

      mean_RMSE = pd.DataFrame(mean_RMSE,columns=['RMSE'])
      stdv_RMSE = pd.DataFrame(stdv_RMSE,columns=['STD RMSE'])
      mean_MAE = pd.DataFrame(mean_MAE,columns=['MAE'])
      stdv_MAE = pd.DataFrame(stdv_MAE,columns=['STD MAE'])

      res_df = pd.concat([metric,level,model,mean_RMSE,stdv_RMSE,mean_MAE,stdv_MAE],axis=1)

      return res_df
    
    else:

      for j in self.ml_algo_list:
        if j == 'PolR':
          #temp_data = self.X[i]
          level.append(self.level)
          #metric.append(self.data_columns[i])

          cnt=0
          RMSE=[]
          MAE=[]
          poly_reg = PolynomialFeatures()
          temp_data = poly_reg.fit_transform(self.X.reshape(-1, 1))
          pol_reg = LinearRegression()
          model.append('PolR')
          warnings.filterwarnings('ignore')
          #print('Metric: ',self.data_columns[i])
          print('Level: ',self.level)
          print('Model: ',j)
          print()
          print("**************************************************************")
          print()
          #print('At i: ',i,' x = ',self.X)
          print()

          for train_index, test_index in kf.split(temp_data):
            cnt = cnt+1
            #print('Fold: ',cnt)
            X_train, X_test = temp_data[train_index], temp_data[test_index]
            y_train, y_test = self.Y[train_index], self.Y[test_index]

            pol_reg.fit(X_train,y_train)
            y_pred = pol_reg.predict(X_test)
            RMSE.append(np.sqrt(mean_squared_error(y_test,y_pred)))
            MAE.append(mean_absolute_error(y_test,y_pred))
          
          mean_RMSE.append(statistics.mean(RMSE))
          stdv_RMSE.append(statistics.pstdev(RMSE))
          mean_MAE.append(statistics.mean(MAE))
          stdv_MAE.append(statistics.pstdev(MAE))

        else:
          
          warnings.filterwarnings('ignore')
          #['Polynomial Regression','MLPRegressor','BayesianRidge','SGD Regressor','XGB Regressor','Decision Tree Regressor','ElasticNet','SVM Regressor',]
          if j == 'MLPR':
            reg = MLPRegressor()
            #print('Metric: ',self.data_columns[i])
            print('Level: ',self.level)
            print('Model: ',j)
            print()
            print("**************************************************************")
            print()
            model.append(j)

          #if j == 'Logistic Regression':
            #reg = LogisticRegression()
            #print('Metric: ',self.data_columns[i])
            #print('Level: ',self.level)
            #print('Model: ',j)

          if j == 'BR':
            reg = BayesianRidge()
            #print('Metric: ',self.data_columns[i])
            print('Level: ',self.level)
            print('Model: ',j)
            print()
            print("**************************************************************")
            print()
            model.append(j)

          if j == 'SGDR':
            reg = SGDRegressor()
            #print('Metric: ',self.data_columns[i])
            print('Level: ',self.level)
            print('Model: ',j)
            print()
            print("**************************************************************")
            print()
            model.append(j)

          if j == 'XGBR':
            reg = XGBRegressor()
            #print('Metric: ',self.data_columns[i])
            print('Level: ',self.level)
            print('Model: ',j)
            print()
            print("**************************************************************")
            print()
            model.append(j)

          if j == 'DTR':
            reg = DecisionTreeRegressor()
            #print('Metric: ',self.data_columns[i])
            print('Level: ',self.level)
            print('Model: ',j)
            print()
            print("**************************************************************")
            print()
            model.append(j)

          if j == 'EN':
            reg = ElasticNet()
            #print('Metric: ',self.data_columns[i])
            print('Level: ',self.level)
            print('Model: ',j)
            print()
            print("**************************************************************")
            print()
            model.append(j)

          if j == 'SVR':
            reg = SVR()
            #print('Metric: ',self.data_columns[i])
            print('Level: ',self.level)
            print('Model: ',j)
            print()
            print("**************************************************************")
            print()
            model.append(j)
          
          #print('At i: ',i,' x = ',self.X_np[:,0])
          #print()
          #temp_data = self.X.reshape(-1, 1)
          #target_scaler = MinMaxScaler()
          #target_scaler.fit(temp_data)
          #temp_data = target_scaler.transform(temp_data)
          level.append(self.level)
          #metric.append(self.data_columns[i])
          temp_data = self.X

          cnt=0
          RMSE=[]
          MAE=[]
          for train_index, test_index in kf.split(temp_data):
            cnt = cnt+1
            #print('Fold: ',cnt)
            X_train, X_test = temp_data[train_index], temp_data[test_index]
            y_train, y_test = self.Y[train_index], self.Y[test_index]

            reg.fit(X_train,y_train)
            y_pred = reg.predict(X_test)
            RMSE.append(np.sqrt(mean_squared_error(y_test,y_pred)))
            MAE.append(mean_absolute_error(y_test,y_pred))

          mean_RMSE.append(statistics.mean(RMSE))
          stdv_RMSE.append(statistics.pstdev(RMSE))
          mean_MAE.append(statistics.mean(MAE))
          stdv_MAE.append(statistics.pstdev(MAE))
      

      

      #break
    #metric = pd.DataFrame(metric,columns=['Metric'])
    level = pd.DataFrame(level,columns=['Level'])
    model = pd.DataFrame(model,columns=['Model'])
    print()

    mean_RMSE = pd.DataFrame(mean_RMSE,columns=['RMSE'])
    stdv_RMSE = pd.DataFrame(stdv_RMSE,columns=['STD RMSE'])
    mean_MAE = pd.DataFrame(mean_MAE,columns=['MAE'])
    stdv_MAE = pd.DataFrame(stdv_MAE,columns=['STD MAE'])

    res_df = pd.concat([level,model,mean_RMSE,stdv_RMSE,mean_MAE,stdv_MAE],axis=1)

    return res_df

# %%
warnings.filterwarnings('ignore')
rtm=ReuseTradML(level='package')
res=rtm.apply_ml()
res

# %%
warnings.filterwarnings('ignore')
rtm=ReuseTradML(level='class_frequency')
res=rtm.apply_ml()
res
# Out:
# Level:  class_frequency
# Model:  PolR
#
# **************************************************************
#
#
# Level:  class_frequency
# Model:  MLPR
#
# **************************************************************
#
# Level:  class_frequency
# Model:  BR
#
# **************************************************************
#
# Level:  class_frequency
# Model:  SGDR
#
# **************************************************************
#
# Level:  class_frequency
# Model:  XGBR
#
# **************************************************************
#
# [00:07:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:07:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:07:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:07:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:07:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:07:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:07:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:07:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:07:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:07:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Level:  class_frequency
# Model:  DTR
#
# **************************************************************
#
# Level:  class_frequency
# Model:  EN
#
# **************************************************************
#
# Level:  class_frequency
# Model:  SVR
#
# **************************************************************
#              Level Model      RMSE  STD RMSE       MAE   STD MAE
# 0  class_frequency  PolR  0.160590  0.108808  0.112904  0.056627
# 1  class_frequency  MLPR  0.161323  0.122559  0.113221  0.056026
# 2  class_frequency    BR  0.152584  0.117237  0.101454  0.053117
# 3  class_frequency  SGDR  0.151727  0.133897  0.088339  0.059167
# 4  class_frequency  XGBR  0.140964  0.117392  0.075506  0.051277
# 5  class_frequency   DTR  0.190341  0.151364  0.108043  0.075303
# 6  class_frequency    EN  0.156521  0.121989  0.106888  0.058815
# 7  class_frequency   SVR  0.156842  0.112999  0.114055  0.059764

# %%
res.to_excel('Results/class_frequencyRes_TraditionalModels.xlsx')
